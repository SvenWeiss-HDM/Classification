# %%
import pandas as pd
import json

# %%
#Hier Datenursprung ändern
with open ("../../Other/dict_artists.json") as datafile:
    data=json.load(datafile)

out1 = pd.DataFrame(data.items(),columns=["artistid","RecommendedArtists"])

# %%
out1
# Out:
#                       artistid  \
# 0       0DheY5irMjBUeLybbCUEZ2
# 1       0DlhY15l3wsrnlfGio2bjU
# 2       0DmRESX2JknGPQyO15yxg7
# 3       0DmhnbHjm1qw6NCYPeZNgJ
# 4       0Dn11fWM7vHQ3rinvWEl4E
# ...                        ...
# 573851  4NUP7lYc6eSVzbCkOR6qnO
# 573852  1JvLsDIsLhgGGavDkyZ12g
# 573853  6c3GG5wvGdDxLoDbzBqDj7
# 573854  36J3tFsGjSSIQYgQVKx3h2
# 573855  54cEPaH0NTifMLjFq3L8Gj
#
#                                        RecommendedArtists
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 573851  [3rqhlSKKMH4J9jl1btwyaB, 2zZjjkd0WsshX6izHBOww...
# 573852  [2zZjjkd0WsshX6izHBOwwL, 6NKA1Pv0yrkoij76XfVJp...
# ...

# %%
out1=out1.explode("RecommendedArtists")
out1
# Out:
#                       artistid      RecommendedArtists
# 0       0DheY5irMjBUeLybbCUEZ2                     NaN
# 1       0DlhY15l3wsrnlfGio2bjU                     NaN
# 2       0DmRESX2JknGPQyO15yxg7                     NaN
# 3       0DmhnbHjm1qw6NCYPeZNgJ                     NaN
# 4       0Dn11fWM7vHQ3rinvWEl4E                     NaN
# ...                        ...                     ...
# 573855  54cEPaH0NTifMLjFq3L8Gj  3cOzi726Iav1toV2LRVEjp
# 573855  54cEPaH0NTifMLjFq3L8Gj  6LogY6VMM3jgAE6fPzXeMl
# 573855  54cEPaH0NTifMLjFq3L8Gj  19boQkDEIay9GaVAWkUhTa
# 573855  54cEPaH0NTifMLjFq3L8Gj  5nvjpU3Y7L6Hpe54QuvDjy
# 573855  54cEPaH0NTifMLjFq3L8Gj  2bP2cNhNBdKXHC6AnqgyVp
#
# [8991376 rows x 2 columns]

# %%
out1.to_csv("../../Other/loadartistrecommends.csv")

# %%
#Hier Datenursprung ändern
data2= pd.read_csv("../../Other/artists.csv")

# %%
data2
# Out:
#                              id  followers            genres  \
# 0        0DheY5irMjBUeLybbCUEZ2        0.0                []
# 1        0DlhY15l3wsrnlfGio2bjU        5.0                []
# 2        0DmRESX2JknGPQyO15yxg7        0.0                []
# 3        0DmhnbHjm1qw6NCYPeZNgJ        0.0                []
# 4        0Dn11fWM7vHQ3rinvWEl4E        2.0                []
# ...                         ...        ...               ...
# 1162090  3cOzi726Iav1toV2LRVEjp     4831.0  ['black comedy']
# 1162091  6LogY6VMM3jgAE6fPzXeMl       46.0                []
# 1162092  19boQkDEIay9GaVAWkUhTa      257.0                []
# 1162093  5nvjpU3Y7L6Hpe54QuvDjy     2357.0  ['black comedy']
# 1162094  2bP2cNhNBdKXHC6AnqgyVp       40.0    ['new comedy']
#
#                                                    name  popularity
# 0        Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                           ปูนา ภาวิณี           0
# ...

# %%
dataartist=data2[["id","name","followers","popularity"]].copy()

# %%
dataartist
# Out:
#                              id  \
# 0        0DheY5irMjBUeLybbCUEZ2
# 1        0DlhY15l3wsrnlfGio2bjU
# 2        0DmRESX2JknGPQyO15yxg7
# 3        0DmhnbHjm1qw6NCYPeZNgJ
# 4        0Dn11fWM7vHQ3rinvWEl4E
# ...                         ...
# 1162090  3cOzi726Iav1toV2LRVEjp
# 1162091  6LogY6VMM3jgAE6fPzXeMl
# 1162092  19boQkDEIay9GaVAWkUhTa
# 1162093  5nvjpU3Y7L6Hpe54QuvDjy
# 1162094  2bP2cNhNBdKXHC6AnqgyVp
#
#                                                    name  followers  popularity
# 0        Armid & Amir Zare Pashai feat. Sara Rouzbehani        0.0           0
# 1                                           ปูนา ภาวิณี        5.0           0
# 2                                                 Sadaa        0.0           0
# 3                                             Tra'gruda        0.0           0
# 4                                Ioannis Panoutsopoulos        2.0           0
# ...                                                 ...        ...         ...
# ...

# %%
dffin= out1.merge(dataartist,left_on="RecommendedArtists",right_on="id")

# %%
dffin
# Out:
#                        artistid      RecommendedArtists  \
# 0        0DvvojCMIqsOT1Btiwvq1h  3Y9UedETQztUmRuB2pYaGR
# 1        6ng2L9Pwj7NeXm0vJW8LLr  3Y9UedETQztUmRuB2pYaGR
# 2        3A6TC7BhsBm8LktswCdm0X  3Y9UedETQztUmRuB2pYaGR
# 3        7ofTH0nFjkbKuRTpazOzzV  3Y9UedETQztUmRuB2pYaGR
# 4        4xirLzVl1nnPPBgUFvFbFh  3Y9UedETQztUmRuB2pYaGR
# ...                         ...                     ...
# 8864467  0cEAbivoHfAomgJM1nCfgO  4JBkBf59CJmzTO4fboBJWH
# 8864468  4NUP7lYc6eSVzbCkOR6qnO  4A7e6SdYhrgg7qoEwBYlyA
# 8864469  6c3GG5wvGdDxLoDbzBqDj7  209v7LjUrpsbsik1AoGXqF
# 8864470  6c3GG5wvGdDxLoDbzBqDj7  3UnAVg2Zel01y5FDxYWHL5
# 8864471  54cEPaH0NTifMLjFq3L8Gj  6LogY6VMM3jgAE6fPzXeMl
#
#                              id               name  followers  popularity
# 0        3Y9UedETQztUmRuB2pYaGR             Rubick       20.0           0
# 1        3Y9UedETQztUmRuB2pYaGR             Rubick       20.0           0
# ...

# %%
dffin.to_csv("../../Other/loadreccomend with followers.csv")
